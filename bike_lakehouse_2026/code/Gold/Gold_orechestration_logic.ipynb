# %% [markdown]
# #Gold Orchestration

# %%
notebooks = [
    "./Gold_dim_customers",
    "./Gold_dim_products",
    "./Gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
